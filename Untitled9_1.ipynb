# %% [markdown]
# Метод 1

# %%
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def generate_throws(n: int) -> list:
    """
    Генерирует список бросков кубика.

    :param n: Количество бросков
    :return: Список случайных значений от 1 до 6
    """
    data = []
    for _ in range(n):
        data.append(random.randint(1, 6))
    return data

# Броски кубика для различных количеств бросков
n_throws_list = [100, 1000, 10000, 1000000]
results = []

for n_throws in n_throws_list:
    kub_data = generate_throws(n_throws)
    results.append(kub_data)
    print(f"Результаты для {n_throws} бросков: {kub_data}")
# Out:
# Результаты для 100 бросков: [3, 4, 5, 1, 6, 4, 3, 3, 1, 5, 6, 2, 6, 1, 6, 6, 2, 3, 5, 4, 5, 4, 6, 5, 2, 2, 5, 5, 6, 2, 3, 6, 2, 4, 2, 2, 4, 4, 2, 4, 5, 2, 5, 2, 6, 5, 6, 2, 3, 5, 6, 3, 2, 4, 6, 6, 4, 5, 3, 2, 5, 2, 3, 1, 4, 4, 1, 4, 5, 4, 1, 5, 5, 6, 5, 2, 2, 6, 5, 6, 2, 5, 2, 3, 6, 5, 2, 5, 4, 5, 5, 6, 5, 5, 5, 2, 2, 1, 4, 5]
# ...

# %%
# Визуализация статистики
fig, axes = plt.subplots(1, len(n_throws_list), figsize=(15, 5))
colors = ['red', 'green', 'blue', 'purple']

for i, n_throws in enumerate(n_throws_list):
    values, counts = np.unique(results[i], return_counts=True)
    axes[i].bar(values, counts / n_throws, color=colors[i], label=f'{n_throws} бросков')
    axes[i].set_xlabel('Значение кубика')
    axes[i].set_ylabel('Частота')
    axes[i].set_title(f'{n_throws} бросков')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Метод 2

# %%
import random
import matplotlib.pyplot as plt
import numpy as np


def generate_throws_sample(n: int) -> list:
    """
    Генерирует список бросков кубика с помощью random.sample().

    :param n: Количество бросков
    :return: Список случайных значений от 1 до 6
    """
    return random.sample(range(1, 7), n)  # Используем random.sample() для получения случайных чисел без повторений

# Броски кубика для различных количеств бросков
n_throws_list = [100, 1000, 10000, 1000000]
results = []

for n_throws in n_throws_list:
    kub_data = generate_throws_sample(n_throws)
    results.append(kub_data)
    print(f"Результаты для {n_throws} бросков: {kub_data}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 20
#      17 results = []
#      19 for n_throws in n_throws_list:
# ---> 20     kub_data = generate_throws_sample(n_throws)
#      21     results.append(kub_data)
#      22     print(f"Результаты для {n_throws} бросков: {kub_data}")
#
# Cell In[8], line 13, in generate_throws_sample(n)
#       6 def generate_throws_sample(n: int) -> list:
#       7     """
#       8     Генерирует список бросков кубика с помощью random.sample().
#       9
#      10     :param n: Количество бросков
#      11     :return: Список случайных значений от 1 до 6
#      12     """
# ---> 13     return random.sample(range(1, 7), n)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\random.py:430, in Random.sample(self, population, k, counts)
#     428 randbelow = self._randbelow
#     429 if not 0 <= k <= n:
# ...

# %% [markdown]
# Метод 3

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def generate_throws_comprehension(n: int) -> list:
    """
    Генерирует список бросков кубика с помощью list comprehension.

    :param n: Количество бросков
    :return: Список случайных значений от 1 до 6
    """
    return [random.randrange(1, 7, 1) for _ in range(n)]  # Используем list comprehension

# Броски кубика для различных количеств бросков
n_throws_list = [100, 1000, 10000, 1000000]
results = []

for n_throws in n_throws_list:
    kub_data = generate_throws_comprehension(n_throws)
    results.append(kub_data)
    print(f"Результаты для {n_throws} бросков: {kub_data}")
# Out:
# Результаты для 100 бросков: [3, 1, 3, 2, 6, 3, 2, 4, 4, 3, 2, 5, 3, 4, 2, 6, 2, 2, 4, 4, 5, 3, 1, 5, 6, 4, 5, 4, 1, 2, 4, 2, 6, 2, 4, 1, 3, 5, 1, 6, 4, 1, 1, 1, 4, 1, 1, 3, 1, 1, 6, 2, 3, 5, 3, 5, 2, 3, 5, 1, 6, 4, 2, 2, 5, 1, 4, 4, 1, 2, 3, 5, 3, 2, 5, 6, 1, 3, 1, 4, 6, 5, 6, 3, 2, 4, 6, 1, 1, 2, 4, 1, 5, 4, 5, 1, 2, 4, 3, 4]
# ...

# %%
# Визуализация статистики
fig, axes = plt.subplots(1, len(n_throws_list), figsize=(15, 5))
colors = ['red', 'green', 'blue', 'purple']

for i, n_throws in enumerate(n_throws_list):
    values, counts = np.unique(results[i], return_counts=True)
    axes[i].bar(values, counts / n_throws, color=colors[i], label=f'{n_throws} бросков')
    axes[i].set_xlabel('Значение кубика')
    axes[i].set_ylabel('Частота')
    axes[i].set_title(f'{n_throws} бросков')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Метод 4

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def generate_throws_for_loop(n: int) -> list:
    """
    Генерирует список бросков кубика с помощью цикла for.

    :param n: Количество бросков
    :return: Список случайных значений от 1 до 6
    """
    data = []
    for _ in range(n):
        data.append(random.randint(1, 6))  # Используем random.randint() для генерации случайных чисел
    return data

# Броски кубика для различных количеств бросков
n_throws_list = [100, 1000, 10000, 1000000]
results = []

for n_throws in n_throws_list:
    kub_data = generate_throws_for_loop(n_throws)
    results.append(kub_data)
    print(f"Результаты для {n_throws} бросков: {kub_data}")
# Out:
# Результаты для 100 бросков: [4, 5, 1, 6, 3, 5, 5, 2, 3, 2, 6, 3, 6, 6, 5, 5, 2, 6, 5, 2, 4, 4, 1, 2, 1, 4, 6, 2, 5, 5, 4, 3, 5, 4, 3, 6, 4, 4, 2, 1, 5, 4, 4, 5, 3, 4, 5, 5, 2, 5, 1, 2, 1, 6, 5, 5, 1, 1, 2, 5, 6, 2, 2, 1, 1, 5, 1, 4, 5, 5, 6, 3, 5, 2, 5, 2, 6, 2, 3, 6, 6, 1, 3, 2, 2, 5, 4, 3, 6, 4, 5, 3, 3, 6, 6, 4, 3, 5, 1, 2]
# ...

# %%
# Визуализация статистики
fig, axes = plt.subplots(1, len(n_throws_list), figsize=(15, 5))
colors = ['red', 'green', 'blue', 'purple']

for i, n_throws in enumerate(n_throws_list):
    values, counts = np.unique(results[i], return_counts=True)
    axes[i].bar(values, counts / n_throws, color=colors[i], label=f'{n_throws} бросков')
    axes[i].set_xlabel('Значение кубика')
    axes[i].set_ylabel('Частота')
    axes[i].set_title(f'{n_throws} бросков')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Метод 5

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_throws_numpy(n: int) -> list:
    """
    Генерирует список бросков кубика с помощью numpy.random.randint().

    :param n: Количество бросков
    :return: Список случайных значений от 1 до 6
    """
    return list(np.random.randint(low=1, high=7, size=n))

# Броски кубика для различных количеств бросков
n_throws_list = [100, 1000, 10000, 1000000]
results = []

for n_throws in n_throws_list:
    kub_data = generate_throws_numpy(n_throws)
    results.append(kub_data)
    print(f"Результаты для {n_throws} бросков: {kub_data}")
# Out:
# Результаты для 100 бросков: [np.int32(4), np.int32(3), np.int32(2), np.int32(5), np.int32(3), np.int32(2), np.int32(6), np.int32(6), np.int32(4), np.int32(1), np.int32(3), np.int32(5), np.int32(6), np.int32(1), np.int32(5), np.int32(2), np.int32(5), np.int32(3), np.int32(6), np.int32(2), np.int32(2), np.int32(3), np.int32(4), np.int32(6), np.int32(5), np.int32(1), np.int32(2), np.int32(3), np.int32(2), np.int32(5), np.int32(5), np.int32(2), np.int32(4), np.int32(4), np.int32(5), np.int32(5), np.int32(2), np.int32(1), np.int32(1), np.int32(2), np.int32(5), np.int32(4), np.int32(2), np.int32(6), np.int32(2), np.int32(5), np.int32(1), np.int32(4), np.int32(2), np.int32(5), np.int32(6), np.int32(5), np.int32(5), np.int32(4), np.int32(4), np.int32(5), np.int32(5), np.int32(4), np.int32(3), np.int32(1), np.int32(3), np.int32(1), np.int32(4), np.int32(6), np.int32(4), np.int32(5), np.int32(3), np.int32(5), np.int32(4), np.int32(3), np.int32(2), np.int32(4), np.int32(6), np.int32(3), np.int3
# ...

# %%
# Визуализация статистики
fig, axes = plt.subplots(1, len(n_throws_list), figsize=(15, 5))
colors = ['red', 'green', 'blue', 'purple']

for i, n_throws in enumerate(n_throws_list):
    values, counts = np.unique(results[i], return_counts=True)
    axes[i].bar(values, counts / n_throws, color=colors[i], label=f'{n_throws} бросков')
    axes[i].set_xlabel('Значение кубика')
    axes[i].set_ylabel('Частота')
    axes[i].set_title(f'{n_throws} бросков')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Метод 6

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_throws_random_sample(n: int) -> list:
    """
    Генерирует список бросков кубика с помощью np.random.random_sample().

    :param n: Количество бросков
    :return: Список случайных значений от 1 до 6
    """
    # Масштабируем случайные числа от 0 до 1 к диапазону от 1 до 6
    return list(np.floor(np.random.random_sample(size=n) * 6) + 1)

# Броски кубика для различных количеств бросков
n_throws_list = [100, 1000, 10000, 1000000]
results = []

for n_throws in n_throws_list:
    kub_data = generate_throws_random_sample(n_throws)
    results.append(kub_data)
    print(f"Результаты для {n_throws} бросков: {kub_data}")
# Out:
# Результаты для 100 бросков: [np.float64(1.0), np.float64(4.0), np.float64(5.0), np.float64(5.0), np.float64(4.0), np.float64(2.0), np.float64(4.0), np.float64(2.0), np.float64(3.0), np.float64(2.0), np.float64(3.0), np.float64(6.0), np.float64(6.0), np.float64(6.0), np.float64(2.0), np.float64(1.0), np.float64(1.0), np.float64(6.0), np.float64(5.0), np.float64(5.0), np.float64(4.0), np.float64(4.0), np.float64(5.0), np.float64(3.0), np.float64(4.0), np.float64(4.0), np.float64(1.0), np.float64(5.0), np.float64(3.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(4.0), np.float64(2.0), np.float64(6.0), np.float64(2.0), np.float64(6.0), np.float64(3.0), np.float64(4.0), np.float64(4.0), np.float64(4.0), np.float64(5.0), np.float64(2.0), np.float64(4.0), np.float64(2.0), np.float64(6.0), np.float64(5.0), np.float64(1.0), np.float64(2.0), np.float64(6.0), np.float64(6.0), np.float64(5.0), np.float64(1.0), np.float64(5.0), np.float64(5.0), np.float64(1.0), np.float64(1.0), 
# ...

# %%
# Визуализация статистики
fig, axes = plt.subplots(1, len(n_throws_list), figsize=(15, 5))
colors = ['red', 'green', 'blue', 'purple']

for i, n_throws in enumerate(n_throws_list):
    values, counts = np.unique(results[i], return_counts=True)
    axes[i].bar(values, counts / n_throws, color=colors[i], label=f'{n_throws} бросков')
    axes[i].set_xlabel('Значение кубика')
    axes[i].set_ylabel('Частота')
    axes[i].set_title(f'{n_throws} бросков')
    axes[i].legend()

plt.tight_layout()
plt.show()
